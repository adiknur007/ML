# %% [markdown]
# <a href="https://colab.research.google.com/github/adiknur007/ML/blob/main/4_%D0%B0%D0%BF%D1%82%D0%B0_%D0%9D%D2%B1%D1%80%D1%82%D0%B0%D0%B5%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 тапсырма

class Rectangle:
  def __init__(self, length: int, width: int):
    self.length: int = length
    self.width: int = width

  def area(self) -> int:
    return self.length * self.width

  def perimeter(self) -> int:
    return 2 * (self.length + self.width)

rect = Rectangle(50, 20)
print("Perimeter:", rect.perimeter())
print("Area:", rect.area())

#2 тапсырма

try:
  a = int(input("Санды енгіз: "))
  b = int(input("Санды енгіз: "))
  print(a / b)
except ValueError as v:
  print("Сан енгізіңіз")
except ZeroDivisionError as zero:
  print(f"Санды нөлге бөлуге болмайды")
finally:
  print("Код аяқталды!")
# Out:
# Perimeter: 140
# Area: 1000
# Санды енгіз: 5
# Санды енгіз: 5
# 1.0
# Код аяқталды!

# %%
#3 тапсырма
from new import add, sub, mul, div
print(add(5, 5))
print(sub(5, 5))
print(mul(5, 5))
print(div(5, 5))
# Out:
# 10
# 0
# 25
# 1.0

# %%
#4 тапсырма
import numpy as np
arr = np.random.randint(2, 10, 5) # 2 мен 10 санның арасындағы 5 санды кездейсоқ алу
print(arr)
print("Avg: ", arr.mean()) # орташа мән
print("Max: ", arr.max()) # Максималды мән
print("Min: ", arr.min()) # Минималды мән
# Out:
# [8 5 2 2 4]
# Avg:  4.2
# Max:  8
# Min:  2
