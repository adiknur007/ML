# %% [markdown]
# <a href="https://colab.research.google.com/github/adiknur007/ML/blob/main/%D0%A2%D0%A24_%D0%B0%D0%BF%D1%82%D0%B0_%D0%9D%D2%B1%D1%80%D1%82%D0%B0%D0%B5%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python-дағы ОББ, ерекше жағдайларды өңдеу (try-except), модульдер мен пакеттер, NumPy кіріспе (массивтер, векторизация, негізгі операциялар)

# %% [markdown]
# 1. Мақсат
# Python тілінде объектілі-бағытталған бағдарламалау (ОББ), ерекше жағдайларды өңдеу (try-except), модульдер мен пакеттермен жұмыс, сондай-ақ NumPy кітапханасындағы негізгі операцияларды меңгеру.

# %% [markdown]
# # Есеп 1.1:
#
# ---
# Кітап (Kitap) атты класс құрыңыз. Бұл кластың атауы (atau) және авторы (avtory) деген екі атрибуты болуы керек.\
# __init__ әдісін қолданып, кітап атауын және авторын инициализациялаңыз.\
# Класс ішінде кітап_туралы_мәлімет (kitap_turaly_malimet) атты әдіс жасаңыз. Бұл әдіс "Кітап: [Атауы], Авторы: [Авторы]" деген мәтінді консольға шығаруы керек.\
# Осы класстан бір нысан (объект) жасаңыз және кітап_туралы_мәлімет әдісін шақырыңыз.

# %%
class Kitap:
    def __init__(self, atau, avtory): #self бұл кілт
        self.atau = atau        # Кітап атауы
        self.avtory = avtory    # Автордың аты

    def kitap_turaly_malimet(self):
        print(f"Кітап: {self.atau}, Авторы: {self.avtory}")

kitap1 = Kitap("Абай жолы", "Мұхтар Әуезов")

print (kitap1.kitap_turaly_malimet())
# Out:
# Кітап: Абай жолы, Авторы: Мұхтар Әуезов
# None

# %% [markdown]
# # Есеп 2.1:
#
# ---
#
# numpy кітапханасын np ретінде импорттаңыз.\
# 1-ден 9-ға дейінгі (9-ды қоса алғанда) сандардан тұратын бір өлшемді NumPy массивін (arr_a) жасаңыз.\
# 3x3 өлшемді (3 жол, 3 баған) сандардан тұратын екі өлшемді NumPy массивін (arr_b) жасаңыз. Мысалы, 1-ден 9-ға дейінгі сандарды пайдаланыңыз.\
# Әр массивтің өлшемін (.shape) және деректер түрін (.dtype) шығарыңыз.

# %%
import numpy as np

arr_a = np.arange(1, 10)   # 1-ден 9-ға дейін массив

arr_b = np.arange(1, 10).reshape(3, 3) #arange 1-10 дейінгі сандардан массив жасайды, ал reshape 3:3 ол 3 баған және 3 жол болсын деген сөз

print("Бір өлшемді массив:", arr_a)
print("Өлшемі:", arr_a.shape) #өлшемін (.shape)
print("Деректер түрі:", arr_a.dtype) #деректер түрін (.dtype)

print("Массив 3 өлшемді", arr_b)
print("Өлшемі:", arr_b.shape) #өлшемін (.shape)
print("Деректер түрі:", arr_b.dtype)#деректер түрін (.dtype)
# Out:
# Бір өлшемді массив: [1 2 3 4 5 6 7 8 9]
# Өлшемі: (9,)
# Деректер түрі: int64
# Массив 3 өлшемді [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# Өлшемі: (3, 3)
# Деректер түрі: int64

# %% [markdown]
# # Есеп 3.1:
#
#
# ---
#
# numpy-ді np ретінде импорттаңыз.\
# Кездейсоқ 5 бүтін саннан тұратын екі бір өлшемді NumPy массивін (vec1 және vec2) жасаңыз (мысалы, 1-ден 10-ға дейінгі).\
# Векторизацияны қолдана отырып (циклсіз):
# - Екі массивті қосыңыз (vec1 + vec2).
# - Әрбір элементтің квадратын есептеңіз (vec1 ** 2).
# vec1 массивінің орташа мәнін (.mean()) және ең үлкен мәнін (.max()) табыңыз.\
#
# Барлық нәтижелерді консольға шығарыңыз.

# %%
import numpy as np

vec1 = np.random.randint(1, 11, size=5)   # 1-10 арасындағы 5 кездейсоқ сан
vec2 = np.random.randint(1, 11, size=5)   # 1-10 арасындағы 5 кездейсоқ сан

sum_vec = vec1 + vec2          # қосу
square_vec1 = vec1 ** 2        # квадрат
mean_vec1 = vec1.mean()        # орташа мән
max_vec1 = vec1.max()          # ең үлкен мән


print("vec1:", vec1)
print("vec2:", vec2)

print("\nқосу:", sum_vec)
print("квадрат:", square_vec1)

print("\nорташа мән:", mean_vec1)
print("ең үлкен мән:", max_vec1)
# Out:
# vec1: [ 6  4  6 10  3]
# vec2: [4 4 6 1 6]
#
# қосу: [10  8 12 11  9]
# квадрат: [ 36  16  36 100   9]
#
# орташа мән: 5.8
# ең үлкен мән: 10
